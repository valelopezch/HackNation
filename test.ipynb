# %%
import pandas as pd

# %%
pd.read_csv("data/jobs_reduced.csv")
# Out:
#                      topic                                  job_title  \
# 0  Artificial Intelligence                   Senior Software Engineer
# 1  Artificial Intelligence          Software Engineer, AI Foundations
# 2  Artificial Intelligence                         AI Agent Developer
# 3  Artificial Intelligence  Forward Deployed AI Engineer - Enterprise
# 4  Artificial Intelligence               Project Lead-App Development
# 5  Artificial Intelligence               Project Lead-App Development
#
#                                site (remote country)  \
# 0                 Redmond, Washington, United States
# 1  New Taipei, Banqiao District, New Taipei City,...
# 2                  Manila, Metro Manila, Philippines
# 3          London, UK, San Francisco & Palo Alto, CA
# 4                INDIA - NOIDA- BIRLASOFT OFFICE, IN
# 5                INDIA - NOIDA- BIRLASOFT OFFICE, IN
#
#                                                tasks  \
# ...
